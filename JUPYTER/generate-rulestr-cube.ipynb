# %%
################ tunable parameters


output_file1='input/input-ltl-r2-12.rules.csv'
#output_file1='input-ltl-r2-18.rules.csv'
# output_file1='input-kjfhkjdshgkdjhgdkgjh.rules.csv'


output_file1='input/input-ltl-r3-16.rules.csv'
# output_file1='input-kjfhkjdshgkdjhgdkgjh.rules.csv'



r=2

bmin0=7; bmax0=7; smin0=7; smax0=10
bmin0=7; bmax0=7; smin0=7; smax0=9
# bmin0=7; bmax0=11; smin0=7; smax0=10
#bmin0=7; bmax0=8; smin0=6; smax0=10
#bmin0=7; bmax0=9; smin0=7; smax0=10
#bmin0=6; bmax0=6; smin0=6; smax0=6
#bmin0=5; bmax0=6; smin0=5; smax0=6
#bmin0=4; bmax0=5; smin0=4; smax0=5

# ndbs=1
ndbmin=1; ndbmax=6; ndsmin=1; ndsmax=2
ndbmin=1; ndbmax=6; ndsmin=1; ndsmax=3
# ndbmin=1; ndbmax=1; ndsmin=1; ndsmax=1
#ndbmin=3; ndbmax=1; ndsmin=3; ndsmax=1
#ndbmin=2; ndbmax=3; ndsmin=2; ndsmax=3
#ndbmin=3; ndbmax=3; ndsmin=3; ndsmax=3
#ndbmin=3; ndbmax=4; ndsmin=3; ndsmax=4
#ndbmin=2; ndbmax=6; ndsmin=2; ndsmax=5
#ndbmin=3; ndbmax=6; ndsmin=3; ndsmax=5
#ndbmin=5; ndbmax=8; ndsmin=5; ndsmax=8




r=3

bmin0=14; bmax0=18; smin0=12; smax0=20
bmin0=12; bmax0=14; smin0=12; smax0=18
bmin0=12; bmax0=14; smin0=12; smax0=19
# bmin0=12; bmax0=15; smin0=12; smax0=19
# bmin0=12; bmax0=16; smin0=12; smax0=18
#bmin0=14; bmax0=20; smin0=13; smax0=22
#bmin0=14; bmax0=20; smin0=12; smax0=21
#bmin0=15; bmax0=21; smin0=11; smax0=23
# bmin0=13; bmax0=18; smin0=13; smax0=23
# bmin0=14; bmax0=25; smin0=16; smax0=23
# bmin0=14; bmax0=24; smin0=16; smax0=24
bmin0=14; bmax0=15; smin0=14; smax0=23
bmin0=14; bmax0=17; smin0=14; smax0=23
bmin0=14; bmax0=18; smin0=14; smax0=23
# bmin0=14; bmax0=19; smin0=14; smax0=23
# bmin0=14; bmax0=17; smin0=13; smax0=22


# to Martin: DON'T FORGET TO COMMENT OUT OLD ONES
bmin0 -= 1; bmax0 -= 1; smin0 -= 1; smax0 -= 1
# bmin0 -= 0; bmax0 -= 1; smin0 -= 0; smax0 -= 1
####bmin0 -= 0; bmax0 -= 0; smin0 -= 1; smax0 -= 0
# bmin0 -= 0; bmax0 -= 0; smin0 -= 1; smax0 -= 1

#r3b12t14s12t19		1
#kjgfdlkfdjgdr3b12t16s12t18		1

##ndbs=3#2#1
ndbmin=3; ndbmax=1; ndsmin=3; ndsmax=1
ndbmin=1; ndbmax=3; ndsmin=1; ndsmax=3
# ndbmin=1; ndbmax=9; ndsmin=1; ndsmax=1
# ndbmin=1; ndbmax=5; ndsmin=3; ndsmax=1
# ndbmin=1; ndbmax=1; ndsmin=3; ndsmax=3
ndbmin=3; ndbmax=3; ndsmin=3; ndsmax=3

# %%
rulestr='b3s23'

# print(rule_s,rulespace,rulestr)
# with open(output_file1,'a') as f1:
#     print(rule_s,rulespace,rulestr, file=f1)




##for dbs in range(-ndbs,ndbs+1):
##for dbs in range(-1,2):

for dbmin in range(ndbmin):

    bmin=bmin0+dbmin

    for dbmax in range(ndbmax):

        bmax=bmax0+dbmax

        for dsmin in range(ndsmin):

            smin=smin0+dsmin

            for dsmax in range(ndsmax):

                smax=smax0+dsmax

                ###########
                

                rulestr='r{}b{}t{}s{}t{}'.format(r,bmin,bmax,smin,smax)
    
                rule_s='rule'
                rulespace='lifelib'
  
                print(rule_s,rulespace,rulestr)
                with open(output_file1,'a') as f1:
                    print(rule_s,rulespace,rulestr, file=f1)
# Out:
# rule lifelib r3b13t17s13t22
# rule lifelib r3b13t17s13t23
# rule lifelib r3b13t17s13t24
# rule lifelib r3b13t17s14t22
# rule lifelib r3b13t17s14t23
# rule lifelib r3b13t17s14t24
# rule lifelib r3b13t17s15t22
# rule lifelib r3b13t17s15t23
# rule lifelib r3b13t17s15t24
# rule lifelib r3b13t18s13t22
# rule lifelib r3b13t18s13t23
# rule lifelib r3b13t18s13t24
# rule lifelib r3b13t18s14t22
# rule lifelib r3b13t18s14t23
# rule lifelib r3b13t18s14t24
# rule lifelib r3b13t18s15t22
# rule lifelib r3b13t18s15t23
# rule lifelib r3b13t18s15t24
# rule lifelib r3b13t19s13t22
# rule lifelib r3b13t19s13t23
# rule lifelib r3b13t19s13t24
# rule lifelib r3b13t19s14t22
# rule lifelib r3b13t19s14t23
# rule lifelib r3b13t19s14t24
# rule lifelib r3b13t19s15t22
# rule lifelib r3b13t19s15t23
# rule lifelib r3b13t19s15t24
# rule lifelib r3b14t17s13t22
# rule lifelib r3b14t17s13t23
# rule lifelib r3b14t17s13t24
# rule lifelib r3b14t17s14t22
# rule lifelib r3b14t17s14t23
# rule lifelib r3b14t17s14t24
# rule lifelib r3b14t17s15t22
# rule lifelib r3b14t17s15t23
# rule lifelib r3b14t17s15t24
# rule lifelib r3b14t18s13t22
# rule lifelib r3b14t18s13t23
# rule lifelib r3b14t18s13t24
# rule lifelib r3b14t18s14t22
# rule lifelib r3b14t18s14t23
# rule lifelib r3b14t18s14t24
# rule lifelib r3b14t18s15t22
# rule lifelib r3b14t18s15t23
# rule lifelib r3b14t18s15t24
# rule lifelib r3b14t19s13t22
# rule lifelib r3b14t19s13t23
# rule lifelib r3b14t19s13t24
# rule lifelib r3b14t19s14t22
# rule lifelib r3b14t19s14t23
# rule lifelib r3b14t19s14t24
# rule lifelib r3b14t19s15t22
# rule lifelib r3b14t19s15t23
# rule lifelib r3b14t19s15t24
# rule lifelib r3b15t17s13t22
# rule lifelib r3b15t17s13t23
# rule lifelib r3b15t17s13t24
# rule lifelib r3b15t17s14t22
# rule lifelib r3b15t17s14t23
# rule lifelib r3b15t17s14t24
# rule lifelib r3b15t17s15t22
# rule lifelib r3b15t17s15t23
# rule lifelib r3b15t17s15t24
# rule lifelib r3b15t18s13t22
# rule lifelib r3b15t18s13t23
# rule lifelib r3b15t18s13t24
# rule lifelib r3b15t18s14t22
# rule lifelib r3b15t18s14t23
# rule lifelib r3b15t18s14t24
# rule lifelib r3b15t18s15t22
# rule lifelib r3b15t18s15t23
# rule lifelib r3b15t18s15t24
# rule lifelib r3b15t19s13t22
# rule lifelib r3b15t19s13t23
# rule lifelib r3b15t19s13t24
# rule lifelib r3b15t19s14t22
# rule lifelib r3b15t19s14t23
# rule lifelib r3b15t19s14t24
# rule lifelib r3b15t19s15t22
# rule lifelib r3b15t19s15t23
# rule lifelib r3b15t19s15t24

# %%
################ tunable parameters
