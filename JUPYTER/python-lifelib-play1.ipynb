# %%
import lifelib

# %%
help(lifelib)
# Out:
# Help on package lifelib:
#
# NAME
#     lifelib
#
# PACKAGE CONTENTS
#     _version
#     autocompile
#     cgold (package)
#     genera (package)
#     pythlib (package)
#     tests (package)
#
# SUBMODULES
#     registry
#
# DATA
#     apilines = '    void* CreateLifetree(int maxmem, int nlayers...  bool ...
#     lifelib_dir = '/home/martin/.local/lib/python3.6/site-packages/lifelib...
#
# VERSION
#     2.3.0
#
# FILE
#     /home/martin/.local/lib/python3.6/site-packages/lifelib/__init__.py

# %%
dir(lifelib)
# Out:
# ['__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__path__',
#  '__spec__',
#  '__version__',
#  '_version',
#  'add_cygdir',
#  'apilines',
#  'autocompile',
#  'compile_rules',
#  'genera',
#  'install_cygwin',
#  'lifelib_dir',
#  'load_rules',
#  'pythlib',
#  'registry',
#  'reset_tree',
#  'run_tests',
#  'sanirule',
#  'set_rules']

# %%
??lifelib.load_rules

# %%
#sess = lifelib.load_rules('r2b7t9s7t14')
#sess = lifelib.load_rules('r2b7t9s7t13',  "r2b7t10s7t13" )
#sess = lifelib.load_rules('r2b7t9s7t15',  "r2b7t10s7t15", 'r2b7t11s7t15' )
sess = lifelib.load_rules( "r2b7t10s7t15" )
# Out:
# Generating code for rules ['r2b7t10s7t15']...
# Compiling lifelib shared object (estimated time: 5.9 seconds)...
# ...compilation complete!

# %%
dir(sess)
# Out:
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  'default_planes',
#  'lifelib',
#  'lifetree',
#  'lifetree_ptrs',
#  'newfloat',
#  'pattern_ptrs',
#  'rules',
#  'verify_rule']

# %%
####dict(sess)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-11-f7a058dc42d5> in <module>()
# ----> 1 dict(sess)
#
# TypeError: 'Session' object is not iterable

# %%
sess.__dict__
# Out:
# {'default_planes': 4,
#  'lifelib': <lifelib.pythlib.lowlevel.WrappedLibrary at 0x7fdf1c0919e8>,
#  'lifetree_ptrs': set(),
#  'pattern_ptrs': set(),
#  'rules': ['r2b7t9s7t10']}

# %%
??sess.lifetree

# %%
lt = sess.lifetree()

# %%
lt.__dict__
# Out:
# {'lifelib': <lifelib.pythlib.lowlevel.WrappedLibrary at 0x7fdf1c0919b0>,
#  'n_layers': 4,
#  'ptr': (27255856,),
#  'session': <lifelib.pythlib.session.Session at 0x7fdf1c0914e0>}

# %%
dir(lt)
# Out:
# ['__class__',
#  '__del__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  'deunify',
#  'download_samples',
#  'hashsoup',
#  'lifelib',
#  'load',
#  'load_timeline',
#  'loadu',
#  'n_layers',
#  'pattern',
#  'ptr',
#  'save_timeline',
#  'session',
#  'unify']

# %%
lt.pattern??

# %%
p1=lt.pattern()

# %%
#####x = 128, y = 173, rule = B3/S23
####x = 128, y = 173
#rle='', rule=None
p1 = lt.pattern('''
20b3o17b3o26bo4b3o17b3o17b3o11b$15b2ob2obo19bob2ob2o20b3o2bo2bo12b2ob
2obo19bob2ob2o6b$15b2o4bob2o13b2obo4b2o13b3o4bob2o4bo12b2o4bob2o13b2ob
o4b2o6b$14bo2bo3bobobo11bobobo3bo2bo11bo2bo5b4o3bo11bo2bo3bobobo11bobo
bo3bo2bo5b
''')

# %%
"""p1 = lt.pattern(rle='''20b3o1bobobo3bo2bo11b3o17b3o11b$15b2ob2obo19bob2ob2o20b3o2bo2bo12b2ob
2obo19bob2ob2o6b$15b2o4bob2o13b2obo4b2o13b3o4bob2o4bo12b2o4bob2o13b2ob
o4b2o6b$14bo2bo3bobobbbo2bo5b ''' ,  rule="r2b7t10s7t12"  )  """

# %%
p1.getrule()
# Out:
# 'r2b7t9s7t10'

# %%
p1.__dict__
# Out:
# {'comments': [],
#  'lifelib': <lifelib.pythlib.lowlevel.WrappedLibrary at 0x7fdf1c0919e8>,
#  'owner': <lifelib.pythlib.session.Lifetree at 0x7fdf1c091c50>,
#  'ptr': (28044336,),
#  'session': <lifelib.pythlib.session.Session at 0x7fdf1c091a20>}

# %%
dir(p1)
# Out:
# ['__add__',
#  '__and__',
#  '__bool__',
#  '__call__',
#  '__class__',
#  '__copy__',
#  '__del__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__gt__',
#  '__hash__',
#  '__iadd__',
#  '__iand__',
#  '__imatmul__',
#  '__imul__',
#  '__init__',
#  '__init_subclass__',
#  '__ior__',
#  '__isub__',
#  '__ixor__',
#  '__le__',
#  '__lshift__',
#  '__lt__',
#  '__matmul__',
#  '__module__',
#  '__mul__',
#  '__ne__',
#  '__new__',
#  '__nonzero__',
#  '__or__',
#  '__pow__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__rshift__',
#  '__setattr__',
#  '__setitem__',
#  '__sizeof__',
#  '__str__',
#  '__sub__',
#  '__subclasshook__',
#  '__weakref__',
#  '__xor__',
#  '_bitshift',
#  '_boolean_immutable',
#  '_boolean_mutable',
#  '_getbound',
#  '_semisolid',
#  '_solid',
#  '_subpops',
#  'advance',
#  'apgcode',
#  'bounding_box',
#  'centre',
#  'comments',
#  'component_containing',
#  'components',
#  'convolve',
#  'coords',
#  'destream',
#  'disjunct',
#  'displacement',
#  'download_samples',
#  'download_synthesis',
#  'empty',
#  'getrect',
#  'getrule',
#  'layers',
#  'lifelib',
#  'match',
#  'nonempty',
#  'onecell',
#  'oscar',
#  'owner',
#  'pdetect_or_advance',
#  'period',
#  'phase_wechsler',
#  'population',
#  'ptr',
#  'replace',
#  'rle_string',
#  'save',
#  'session',
#  'shift',
#  'stream',
#  'transform',
#  'viewer',
#  'wechsler',
#  'write_file',
#  'write_rle']

# %%
p1.bounding_box

# %%
p1.getrect()

# %%
p1.layers()
# Out:
# (<Pattern(logdiam=5, beszel_index=0, ulqoma_index=0, rule=r2b7t9s7t10) owned by <lifelib.pythlib.session.Lifetree object at 0x7fdf1c091c50>>,
#  <Pattern(logdiam=5, beszel_index=0, ulqoma_index=0, rule=r2b7t9s7t10) owned by <lifelib.pythlib.session.Lifetree object at 0x7fdf1c091c50>>,
#  <Pattern(logdiam=5, beszel_index=0, ulqoma_index=0, rule=r2b7t9s7t10) owned by <lifelib.pythlib.session.Lifetree object at 0x7fdf1c091c50>>,
#  <Pattern(logdiam=5, beszel_index=0, ulqoma_index=0, rule=r2b7t9s7t10) owned by <lifelib.pythlib.session.Lifetree object at 0x7fdf1c091c50>>)

# %%
w2=2000#256#128#16#25#16
h2=16

niter =10000#800 #6000#2400 #300#150# 600 #300 #400 #200 #1000 #3000   
step1=12 #4 #20 #8 #15 #5 #1 #37 #2
step2=12#60 #120 #1

p1=lt.pattern()

# %%
p=0.5 #0.3#0.5 #0.25 #0.16
##a[ h0 : h0+h2 , w0 : w0+w2 ] = (rand( h2, w2 )<p) 
p1[0:h2, 0:w2] = p


bb=p1.bounding_box
/print bb
bb[2]-bb[0]
# Out:
# [0, 0, 16, 2000]
# 16

# %%
pops = []
gens = []

currgen = 0

for _ in range(int(niter/step2)):
    pops.append(p1.population)
    gens.append(currgen)
    p1 = p1[step2]
    currgen += step2

bb=p1.bounding_box
/print bb
bb[2]-bb[0]
# Out:
# [-3331, -2049, 6679, 6149]
# 10010

# %%
# %matplotlib notebook
#%matplotlib inline
from matplotlib import pyplot as plt

plt.figure(figsize=(8,4))
plt.plot(gens, pops)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="800">
